# %% [markdown]
# # COMPUTER LAB 3
#
# Work through the "Third Computer Lab" (Chapter 9) in _A Student's Guide to Python._  This exercise illustrates how to work with images in Python.
#
# You can use this notebook to store your code, plots, and notes, or you can write a ___script___ (see Section 3.3) that will carry out the analysis and produce the plots, and simply write your comments and observations in this notebook.  If you write a script, it should save your plots and images to PDF, JPG, or PNG files in this folder when it runs.

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.signal import convolve

# %%
impulse = np.zeros((51,51))
impulse[25,25] = 1.0
my_filter = np.ones((3,3))/9
response = convolve(impulse, my_filter)

plt.figure()
plt.imshow(response)

# %%
impulse = np.zeros((51,51))
impulse[25,25] = 1.0
my_filter = np.ones((3,3))/9
response = convolve(impulse, my_filter, mode = 'valid')

plt.figure()
plt.imshow(response)

# %% [markdown]
# # Averaging Filter

# %%
GaussFilter = np.loadtxt('gauss_filter.csv',delimiter=',')
CatPhoto = plt.imread('bwCat.tif')

# %%
plt.imshow(CatPhoto);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')

# %% [markdown]
# ## a.

# %%
#Small Square Filter
my_filter = np.ones((3,3))/9

# %% [markdown]
# It makes sense to use 1/9 because the array is a 3x3

# %% [markdown]
# ## b.

# %%
plt.imshow(CatPhoto);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')

response = convolve(CatPhoto, my_filter, mode = 'valid')

plt.figure()

plt.imshow(response);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')

# %% [markdown]
# It looks like the details around the cats face are lighter but overall the photos look very similar to me.

# %% [markdown]
# ## c.

# %%
# Big Square Filter
BS_filter = np.ones((15,15))/225

plt.imshow(CatPhoto);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')

response = convolve(CatPhoto, BS_filter, mode = 'valid')

plt.figure()

plt.imshow(response);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')

# %% [markdown]
# The filter blurs the entire photo. The details are lost. The blurring is more apparant with the big square filter

# %% [markdown]
# ## d.

# %%
# Values around (100,100) involved would make a 3 x 3 array with 100, 100 in the middle

value = my_filter * CatPhoto[]
# Out:
#   File "C:\Users\jassi\AppData\Local\Temp/ipykernel_13640/1930488361.py", line 3
#     value = my_filter * CatPhoto[]
#                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Smoothing with a Gaussian

# %% [markdown]
# ## a.

# %%
gauss = np.loadtxt('gauss_filter.csv',delimiter=',')

plt.imshow(CatPhoto);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')

ResponseG = convolve(CatPhoto, gauss)

plt.figure()

plt.imshow(ResponseG);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')

# %% [markdown]
# ## b.

# %%
plt.imshow(ResponseG[100:101,100:101]);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')

ResponseSF = convolve(CatPhoto, my_filter, mode = 'valid')

plt.figure()

plt.imshow(ResponseSF[100:101,100:101]);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')

# %% [markdown]
# ## c.

# %%
from mpl_toolkits.mplot3d import Axes3D

plt.imshow(ResponseG[100:101,100:101]);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')

ResponseSF = convolve(CatPhoto, my_filter, mode = 'valid')

plt.figure()

plt.imshow(ResponseSF[100:101,100:101]);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')

ax = Axes3D(plt.figure())
ax.plot_surface(X,Y,Z, rstride=1,cstride=1)
# Out:
# C:\Users\jassi\AppData\Local\Temp/ipykernel_13640/4019066493.py:25: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(plt.figure())
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13640/4019066493.py in <module>
#      24
#      25 ax = Axes3D(plt.figure())
# ---> 26 ax.plot_surface(X,Y,Z, rstride=1,cstride=1)
#
# NameError: name 'X' is not defined

# %% [markdown]
# Convolution takes two inputs and outputs one number. Array one times array two. A square filter averages all values by the same quantity. The Guassian filter should be more smooth around the edges of each cell. It should have smoother transitions.

# %% [markdown]
# # Denoising an image

# %% [markdown]
# ## a.

# %%
Noisy = 0.05 * CatPhoto

plt.imshow(CatPhoto);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')


plt.figure()

plt.imshow(Noisy);

plt.set_cmap('gray');
plt.axis('off');

fig = plt.gcf()

fig.set_facecolor('white')

# %% [markdown]
# ## b.

# %%
#Small Filter
ResponseSF = convolve(Noisy, my_filter)

#Big Filter
ResponseBF = convolve(Noisy, BS_filter)

#Gaussian Filter
ResponseG = convolve(Noisy, gauss)

plt.imshow(Noisy);

plt.set_cmap('gray');
plt.axis('off');
fig = plt.gcf()
fig.set_facecolor('white')

plt.figure()

plt.imshow(ResponseSF);
plt.set_cmap('gray');
plt.axis('off');
fig = plt.gcf()
fig.set_facecolor('white')

plt.figure()

plt.imshow(ResponseBF);
plt.set_cmap('gray');
plt.axis('off');
fig = plt.gcf()
fig.set_facecolor('white')

plt.figure()

plt.imshow(ResponseG);
plt.set_cmap('gray');
plt.axis('off');
fig = plt.gcf()
fig.set_facecolor('white')

# %% [markdown]
# The small filter maybe does improve the image but each of these filters has a blurring effect.

# %% [markdown]
# # Emphasizing Features

# %% [markdown]
# ## a.

# %%
StressFibers = np.loadtxt('stressFibers.csv',delimiter=',')

plt.imshow(StressFibers);

plt.set_cmap('gray');
plt.axis('off');
fig = plt.gcf()
fig.set_facecolor('white')

# %%
v = np.arange(-25,26)
X,Y = np.meshgrid(v,v)
gauss_filter = np.exp(-0.5 * (X**2/2 + Y**2/45))


from mpl_toolkits.mplot3d import Axes3D

ax = Axes3D(plt.figure())
ax.plot_surface(X,Y,Z, rstride=1,cstride=1)
# Out:
# C:\Users\jassi\AppData\Local\Temp/ipykernel_13640/2889327606.py:8: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(plt.figure())
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13640/2889327606.py in <module>
#       7
#       8 ax = Axes3D(plt.figure())
# ----> 9 ax.plot_surface(X,Y,Z, rstride=1,cstride=1)
#
# NameError: name 'Z' is not defined
